-- %%
CREATE CATALOG IF NOT EXISTS bis_prod;

CREATE SCHEMA IF NOT EXISTS bis_prod.bronze_roster;

CREATE SCHEMA IF NOT EXISTS bis_prod.silver_roster;

CREATE VOLUME IF NOT EXISTS bis_prod.bronze_roster.manual_inputs;

-- TRUNCATE TABLE bis_prod.bronze_roster.emp_storage_location;

-- DROP TABLE IF EXISTS bis_prod.bronze_roster.emp_storage_location;

-- DROP MATERIALIZED VIEW IF EXISTS bis_prod.silver_roster.emp_storage_location;

-- DROP VOLUME IF EXISTS bis_prod.bronze_roster.manual_inputs;

-- DROP SCHEMA IF EXISTS bis_prod.bronze_roster;

-- DROP SCHEMA IF EXISTS bis_prod.silver_roster CASCADE;
